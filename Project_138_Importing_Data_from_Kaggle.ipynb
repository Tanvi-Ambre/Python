# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvi-Ambre/Python/blob/main/Project_138_Importing_Data_from_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gspmoreira/articles-sharing-reading-from-cit-deskdrop

# %%
# !ls

# %%
# !unzip articles-sharing-reading-from-cit-deskdrop.zip

# %%
# !ls

# %%
import pandas as pd 
import numpy as np 

df1=pd.read_csv('shared_articles.csv')
df2=pd.read_csv('users_interactions.csv')

# %%
df1.head()
# Out:
#     timestamp        eventType            contentId       authorPersonId  \
# 0  1459192779  CONTENT REMOVED -6451309518266745024  4340306774493623681
# 1  1459193988   CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146   CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474   CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497   CONTENT SHARED  2448026894306402386  4340306774493623681
#
#        authorSessionId  authorUserAgent  authorRegion  authorCountry  \
# 0  8940341205206233829              NaN           NaN            NaN
# 1  8940341205206233829              NaN           NaN            NaN
# 2  8940341205206233829              NaN           NaN            NaN
# 3 -1457532940883382585              NaN           NaN            NaN
# 4  8940341205206233829              NaN           NaN            NaN
#
#   contentType                                                url  \
# ...

# %%
df2.head()
# Out:
#     timestamp eventType     contentId      personId     sessionId  \
# 0  1465413032      VIEW -3.499919e+18 -8.845299e+18  1.264197e+18
# 1  1465412560      VIEW  8.890721e+18 -1.032019e+18  3.621738e+18
# 2  1465416190      VIEW  3.105155e+17 -1.130272e+18  2.631864e+18
# 3  1465413895    FOLLOW  3.105155e+17  3.442809e+17 -3.167638e+18
# 4  1465412290      VIEW -7.820641e+18 -4.453371e+17  5.611481e+18
#
#                                            userAgent userRegion userCountry
# 0                                                NaN        NaN         NaN
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...         NY          US
# 2                                                NaN        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4                                                NaN        NaN         NaN
